# %%
# !jupyter nbconvert --to html "C:/xampp/htdocs/ml_personalNGroup/Group/chalenge2/notebooks/03-modeling.ipynb"
# Out:
# [NbConvertApp] Converting notebook C:/xampp/htdocs/ml_personalNGroup/Group/chalenge2/notebooks/03-modeling.ipynb to html
# [NbConvertApp] WARNING | Alternative text is missing on 1 image(s).
# [NbConvertApp] Writing 622417 bytes to C:\xampp\htdocs\ml_personalNGroup\Group\chalenge2\notebooks\03-modeling.html

# %% [markdown]
# ## Tải dữ liệu đã làm sạch

# %%
import pandas as pd

# Đọc dữ liệu đã xử lý
df_train_clean = pd.read_csv("../data/03_processed/train_clean.csv")
df_test_clean = pd.read_csv("../data/03_processed/test_clean.csv")

print(df_train_clean.shape, df_test_clean.shape)
df_train_clean.head()
# Out:
# (1460, 264) (1459, 263)
#          Id  MSSubClass  LotFrontage   LotArea  OverallQual  OverallCond  \
# 0 -1.730865    0.073375    -0.231877 -0.207142     0.651479    -0.517200
# 1 -1.728492   -0.872563     0.437043 -0.091886    -0.071836     2.179628
# 2 -1.726120    0.073375    -0.098093  0.073480     0.651479    -0.517200
# 3 -1.723747    0.309859    -0.454850 -0.096897     0.651479    -0.517200
# 4 -1.721374    0.073375     0.615421  0.375148     1.374795    -0.517200
#
#    YearBuilt  YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_Oth  \
# 0   1.050994      0.878668    0.514104    0.575425  ...         False
# 1   0.156734     -0.429577   -0.570750    1.171992  ...         False
# 2   0.984752      0.830215    0.325915    0.092907  ...         False
# 3  -1.863632     -0.720298   -0.570750   -0.499274  ...         False
# 4   0.951632      0.733308    1.366489    0.463568  ...         False
#
#    SaleType_WD  SaleCondition_AdjLand  SaleCondition_Alloca  \
# 0         True                  False                 False
# 1         True                  False                 False
# 2         True                  False                 False
# 3         True                  False                 False
# 4         True                  False                 False
#
#    SaleCondition_Family  SaleCondition_Normal  SaleCondition_Partial  \
# 0                 False                  True                  False
# 1                 False                  True                  False
# 2                 False                  True                  False
# 3                 False                 False                  False
# 4                 False                  True                  False
#
#     TotalSF  TotalBathrooms       Age
# 0 -0.001277        1.642256 -1.043259
# 1 -0.052407        0.368581 -0.183465
# 2  0.169157        1.642256 -0.977121
# 3 -0.114493       -0.268257  1.800676
# 4  0.944631        1.642256 -0.944052
#
# [5 rows x 264 columns]

# %% [markdown]
# ## Chuẩn bị dữ liệu huấn luyện

# %%
# Biến mục tiêu (đã log-transform)
y_train = df_train_clean['SalePrice']

# Đặc trưng đầu vào
X_train = df_train_clean.drop(['SalePrice', 'Id'], axis=1)

# Dữ liệu test
X_test = df_test_clean.drop('Id', axis=1)

# %% [markdown]
# ## Chia dữ liệu thành Train và Validation

# %%
from sklearn.model_selection import train_test_split

X_train_split, X_val, y_train_split, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42
)

print("Train size:", X_train_split.shape)
print("Validation size:", X_val.shape)
# Out:
# Train size: (1168, 262)
# Validation size: (292, 262)

# %%
from sklearn.model_selection import train_test_split
import pandas as pd
from datetime import datetime

# --- Chia dữ liệu ---
X_train_split, X_val, y_train_split, y_val = train_test_split(
    X_train, y_train, test_size=0.2, random_state=42
)

print("Train size:", X_train_split.shape)
print("Validation size:", X_val.shape)

# --- Ghi log (3 cột: thời gian, nội dung, kết luận) ---
log_data = {
    "Thời gian chạy": [datetime.now().strftime("%Y-%m-%d %H:%M:%S")],
    "Nội dung làm": ["Chia dữ liệu train/validation 80/20 cho mô hình XGBoost"],
    "Kết luận": ["Dữ liệu đã được chia hợp lý giúp đánh giá mô hình khách quan, tránh overfitting"]
}

log_df = pd.DataFrame(log_data)
log_df.to_excel("../reports/modeling.xlsx", index=False)

print("\nĐã ghi log vào file: modeling.xlsx")
# Out:
# Train size: (1168, 262)
# Validation size: (292, 262)
#
# Đã ghi log vào file: modeling.xlsx

# %% [markdown]
# ## Huấn luyện với mô hình tuyến tính Ridge Regression

# %%
import pandas as pd
from sklearn.metrics import mean_squared_error
import numpy as np

model_ridge = Ridge(alpha=10)
model_ridge.fit(X_train_split, y_train_split)

# Dự đoán trên tập validation
preds_ridge = model_ridge.predict(X_val)

# %% [markdown]
# RMSLE giúp mô hình đánh giá sai lệch theo tỷ lệ (%) thay vì giá trị tuyệt đối — điều này hợp lý khi dự đoán giá nhà, vốn có sự chênh lệch lớn giữa các nhóm giá.

# %%
# Tính RMSE (RMSLE)
rmse_ridge = np.sqrt(mean_squared_error(y_val, preds_ridge))
print(f"RMSE của Ridge: {rmse_ridge:.5f}")
# Out:
# RMSE của Ridge: 0.13902

# %% [markdown]
# Giá trị RMSE = 0.34816 (tính trên dữ liệu đã log-transform) tương ứng với RMSLE ≈ 0.35, tức là sai lệch trung bình khoảng:
#
# 𝑒^
# 0.34816
# −
# 1
# ≈
# 41.6
# %
#
#
# → Trung bình mô hình dự đoán giá nhà lệch khoảng 41% so với thực tế.

# %% [markdown]
# Nhận xét:
#
# Giá trị RMSE = 0.34816 của Ridge Regression là ổn. Mô hình đã học được xu hướng dữ liệu, nhưng cần thêm đặc trưng và mô hình phi tuyến để đạt độ chính xác cao hơn

# %% [markdown]
# ## Thử các mô hình nâng cao

# %%
from sklearn.ensemble import RandomForestRegressor
from xgboost import XGBRegressor
from lightgbm import LGBMRegressor

models = {
    "Ridge": Ridge(alpha=10),
    "RandomForest": RandomForestRegressor(n_estimators=200, random_state=42),
    "XGBoost": XGBRegressor(n_estimators=500, learning_rate=0.05, max_depth=4, random_state=42),
    "LightGBM": LGBMRegressor(n_estimators=500, learning_rate=0.05, random_state=42)
}

results = []

for name, model in models.items():
    model.fit(X_train_split, y_train_split)
    preds = model.predict(X_val)
    rmse = np.sqrt(mean_squared_error(y_val, preds))
    results.append((name, rmse))
    print(f"{name}: RMSE = {rmse:.5f}")

results_df = pd.DataFrame(results, columns=["Model", "RMSE"]).sort_values("RMSE")
results_df
# Out:
# Ridge: RMSE = 0.13902
# RandomForest: RMSE = 0.14756
# XGBoost: RMSE = 0.13902
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.001049 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3557
# [LightGBM] [Info] Number of data points in the train set: 1168, number of used features: 172
# [LightGBM] [Info] Start training from score 12.030658
# LightGBM: RMSE = 0.13857
#           Model      RMSE
# 3      LightGBM  0.138569
# 2       XGBoost  0.139023
# 0         Ridge  0.139024
# 1  RandomForest  0.147560

# %% [markdown]
# ## Huấn luyện mô hình tốt nhất (XGBoost) trên toàn bộ dữ liệu

# %% [markdown]
# Sử dụng Optuna tìm siêu tham số tối ưu bằng kỹ thuật Bayesian optimization để tối ưu hóa hiệu suất

# %%
import optuna
from sklearn.model_selection import cross_val_score
from xgboost import XGBRegressor

def objective(trial):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 300, 800),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.1),
        'max_depth': trial.suggest_int('max_depth', 3, 7),
        'subsample': trial.suggest_float('subsample', 0.7, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.7, 1.0),
        'gamma': trial.suggest_float('gamma', 0, 0.3),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 6)
    }

    model = XGBRegressor(**params, random_state=42)
    scores = cross_val_score(model, X_train_split, y_train_split,
                             scoring='neg_root_mean_squared_error', cv=3)
    return -scores.mean()

study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=30)

print("Best parameters:", study.best_params)
print("Best RMSE (CV):", study.best_value)
# Out:
# [I 2025-10-27 20:21:14,872] A new study created in memory with name: no-name-445db97d-49d2-4259-a303-70d6875b446e
# [I 2025-10-27 20:21:16,762] Trial 0 finished with value: 0.1319525021105299 and parameters: {'n_estimators': 398, 'learning_rate': 0.0822486780826944, 'max_depth': 5, 'subsample': 0.8169255708562411, 'colsample_bytree': 0.782467733988577, 'gamma': 0.10169167175248157, 'min_child_weight': 4}. Best is trial 0 with value: 0.1319525021105299.
# [I 2025-10-27 20:21:18,342] Trial 1 finished with value: 0.13899187598673135 and parameters: {'n_estimators': 332, 'learning_rate': 0.055372713198473776, 'max_depth': 7, 'subsample': 0.9456367705263524, 'colsample_bytree': 0.920134057401605, 'gamma': 0.20286819495237055, 'min_child_weight': 3}. Best is trial 0 with value: 0.1319525021105299.
# [I 2025-10-27 20:21:20,910] Trial 2 finished with value: 0.1314301384636425 and parameters: {'n_estimators': 719, 'learning_rate': 0.09513879539477425, 'max_depth': 4, 'subsample': 0.7573800713896225, 'colsample_bytree': 0.7441468491129365, 'gamma': 0.08749384828273513, 'min_child_weight': 2}. Best is trial 2 with value: 0.1314301384636425.
# [I 2025-10-27 20:21:23,501] Trial 3 finished with value: 0.13039096250894744 and parameters: {'n_estimators': 509, 'learning_rate': 0.015691756498870918, 'max_depth': 6, 'subsample': 0.8043938791792294, 'colsample_bytree': 0.8046388587600501, 'gamma': 0.06815277192699588, 'min_child_weight': 6}. Best is trial 3 with value: 0.13039096250894744.
# [I 2025-10-27 20:21:25,112] Trial 4 finished with value: 0.1286020724277957 and parameters: {'n_estimators': 383, 'learning_rate': 0.04485705149066081, 'max_depth': 3, 'subsample': 0.8637878211943305, 'colsample_bytree': 0.8129110042328715, 'gamma': 0.0689483855815219, 'min_child_weight': 3}. Best is trial 4 with value: 0.1286020724277957.
# [I 2025-10-27 20:21:27,711] Trial 5 finished with value: 0.13377640718884806 and parameters: {'n_estimators': 708, 'learning_rate': 0.049551135251053646, 'max_depth': 3, 'subsample': 0.7602287561025638, 'colsample_bytree': 0.760854643228065, 'gamma': 0.2190513993573046, 'min_child_weight': 4}. Best is trial 4 with value: 0.1286020724277957.
# [I 2025-10-27 20:21:30,081] Trial 6 finished with value: 0.13773853373122905 and parameters: {'n_estimators': 383, 'learning_rate': 0.011172122271330475, 'max_depth': 7, 'subsample': 0.8248653901656332, 'colsample_bytree': 0.9439227000539736, 'gamma': 0.15926981124029996, 'min_child_weight': 1}. Best is trial 4 with value: 0.1286020724277957.
# [I 2025-10-27 20:21:32,653] Trial 7 finished with value: 0.13258045816316735 and parameters: {'n_estimators': 651, 'learning_rate': 0.09789590493807787, 'max_depth': 6, 'subsample': 0.7599448576461679, 'colsample_bytree': 0.9236326059170408, 'gamma': 0.12812893864164093, 'min_child_weight': 5}. Best is trial 4 with value: 0.1286020724277957.
# [I 2025-10-27 20:21:34,589] Trial 8 finished with value: 0.13597554985310548 and parameters: {'n_estimators': 528, 'learning_rate': 0.09606259502154196, 'max_depth': 7, 'subsample': 0.7231660993084957, 'colsample_bytree': 0.8361592173647874, 'gamma': 0.1708759492195735, 'min_child_weight': 4}. Best is trial 4 with value: 0.1286020724277957.
# [I 2025-10-27 20:21:37,228] Trial 9 finished with value: 0.13572872842218514 and parameters: {'n_estimators': 721, 'learning_rate': 0.02674691195582321, 'max_depth': 3, 'subsample': 0.8689423077692778, 'colsample_bytree': 0.9607707229628712, 'gamma': 0.19807261914452742, 'min_child_weight': 6}. Best is trial 4 with value: 0.1286020724277957.
# [I 2025-10-27 20:21:39,285] Trial 10 finished with value: 0.12583455565528892 and parameters: {'n_estimators': 459, 'learning_rate': 0.050199898969770805, 'max_depth': 4, 'subsample': 0.9982722309560665, 'colsample_bytree': 0.7051547376638797, 'gamma': 0.003683642987204472, 'min_child_weight': 2}. Best is trial 10 with value: 0.12583455565528892.
# [I 2025-10-27 20:21:41,490] Trial 11 finished with value: 0.12481803202680726 and parameters: {'n_estimators': 454, 'learning_rate': 0.048355891614888416, 'max_depth': 4, 'subsample': 0.9682131776447656, 'colsample_bytree': 0.701989308962176, 'gamma': 0.0019585617269943095, 'min_child_weight': 2}. Best is trial 11 with value: 0.12481803202680726.
# [I 2025-10-27 20:21:43,305] Trial 12 finished with value: 0.12808142641489953 and parameters: {'n_estimators': 466, 'learning_rate': 0.06620627825971467, 'max_depth': 4, 'subsample': 0.9991144959892129, 'colsample_bytree': 0.7074418795967744, 'gamma': 0.016744580796444756, 'min_child_weight': 1}. Best is trial 11 with value: 0.12481803202680726.
# [I 2025-10-27 20:21:46,181] Trial 13 finished with value: 0.12658806244905887 and parameters: {'n_estimators': 598, 'learning_rate': 0.03684537194264121, 'max_depth': 4, 'subsample': 0.9888859806623297, 'colsample_bytree': 0.7086923682444918, 'gamma': 0.0005472682656637695, 'min_child_weight': 2}. Best is trial 11 with value: 0.12481803202680726.
# [I 2025-10-27 20:21:47,962] Trial 14 finished with value: 0.14024381716458592 and parameters: {'n_estimators': 459, 'learning_rate': 0.06313475718622698, 'max_depth': 5, 'subsample': 0.9260843185909191, 'colsample_bytree': 0.8833347162130615, 'gamma': 0.2879224119649201, 'min_child_weight': 2}. Best is trial 11 with value: 0.12481803202680726.
# [I 2025-10-27 20:21:50,223] Trial 15 finished with value: 0.1279681613732266 and parameters: {'n_estimators': 582, 'learning_rate': 0.07163973475141976, 'max_depth': 4, 'subsample': 0.9320272439299615, 'colsample_bytree': 0.7448286347111097, 'gamma': 0.03671396968517656, 'min_child_weight': 2}. Best is trial 11 with value: 0.12481803202680726.
# [I 2025-10-27 20:21:52,200] Trial 16 finished with value: 0.1311930829415787 and parameters: {'n_estimators': 456, 'learning_rate': 0.03211652298783067, 'max_depth': 5, 'subsample': 0.964146645297804, 'colsample_bytree': 0.7018223757118078, 'gamma': 0.04476729235576911, 'min_child_weight': 1}. Best is trial 11 with value: 0.12481803202680726.
# [I 2025-10-27 20:21:55,995] Trial 17 finished with value: 0.12426823835659428 and parameters: {'n_estimators': 795, 'learning_rate': 0.041781133811210534, 'max_depth': 4, 'subsample': 0.9004238636768309, 'colsample_bytree': 0.8861701514544139, 'gamma': 0.0007839147453102702, 'min_child_weight': 3}. Best is trial 17 with value: 0.12426823835659428.
# [I 2025-10-27 20:21:59,132] Trial 18 finished with value: 0.13418750158022896 and parameters: {'n_estimators': 788, 'learning_rate': 0.021286961187831646, 'max_depth': 5, 'subsample': 0.8964597710440938, 'colsample_bytree': 0.868700302581623, 'gamma': 0.11245261385639885, 'min_child_weight': 3}. Best is trial 17 with value: 0.12426823835659428.
# [I 2025-10-27 20:22:02,115] Trial 19 finished with value: 0.13918934274863637 and parameters: {'n_estimators': 784, 'learning_rate': 0.04011695604761732, 'max_depth': 3, 'subsample': 0.8999163641219065, 'colsample_bytree': 0.9876429829393847, 'gamma': 0.2648418073757506, 'min_child_weight': 5}. Best is trial 17 with value: 0.12426823835659428.
# [I 2025-10-27 20:22:03,521] Trial 20 finished with value: 0.13325887814951323 and parameters: {'n_estimators': 301, 'learning_rate': 0.07754542889987288, 'max_depth': 6, 'subsample': 0.8985087563878913, 'colsample_bytree': 0.8951698362391607, 'gamma': 0.03991743528772576, 'min_child_weight': 3}. Best is trial 17 with value: 0.12426823835659428.
# [I 2025-10-27 20:22:05,633] Trial 21 finished with value: 0.12633987461068516 and parameters: {'n_estimators': 488, 'learning_rate': 0.056125074515340746, 'max_depth': 4, 'subsample': 0.9691728224064105, 'colsample_bytree': 0.8539097142630597, 'gamma': 0.006193703262785231, 'min_child_weight': 2}. Best is trial 17 with value: 0.12426823835659428.
# [I 2025-10-27 20:22:07,810] Trial 22 finished with value: 0.12912703718403548 and parameters: {'n_estimators': 577, 'learning_rate': 0.04826838404848628, 'max_depth': 4, 'subsample': 0.966856767707616, 'colsample_bytree': 0.7466318890049377, 'gamma': 0.03427035346780839, 'min_child_weight': 2}. Best is trial 17 with value: 0.12426823835659428.
# [I 2025-10-27 20:22:09,584] Trial 23 finished with value: 0.13342737948654498 and parameters: {'n_estimators': 412, 'learning_rate': 0.0322127154637889, 'max_depth': 4, 'subsample': 0.9996212777854856, 'colsample_bytree': 0.8278236341990721, 'gamma': 0.06201044344789454, 'min_child_weight': 3}. Best is trial 17 with value: 0.12426823835659428.
# [I 2025-10-27 20:22:11,980] Trial 24 finished with value: 0.12580190863361904 and parameters: {'n_estimators': 622, 'learning_rate': 0.04250514785640632, 'max_depth': 3, 'subsample': 0.9425230639226632, 'colsample_bytree': 0.7838946072641643, 'gamma': 0.01936358648876804, 'min_child_weight': 1}. Best is trial 17 with value: 0.12426823835659428.
# [I 2025-10-27 20:22:14,457] Trial 25 finished with value: 0.12576035760586152 and parameters: {'n_estimators': 646, 'learning_rate': 0.04050140098970971, 'max_depth': 3, 'subsample': 0.9352524036773179, 'colsample_bytree': 0.7844801771925104, 'gamma': 0.02260386485303011, 'min_child_weight': 1}. Best is trial 17 with value: 0.12426823835659428.
# [I 2025-10-27 20:22:16,786] Trial 26 finished with value: 0.12842132577294407 and parameters: {'n_estimators': 660, 'learning_rate': 0.05985048474408773, 'max_depth': 3, 'subsample': 0.9151736244813208, 'colsample_bytree': 0.7796175981333681, 'gamma': 0.06059108662862542, 'min_child_weight': 1}. Best is trial 17 with value: 0.12426823835659428.
# [I 2025-10-27 20:22:19,508] Trial 27 finished with value: 0.12926892343381408 and parameters: {'n_estimators': 751, 'learning_rate': 0.0336614499903696, 'max_depth': 3, 'subsample': 0.8810524909165884, 'colsample_bytree': 0.7270037984564823, 'gamma': 0.0849919719431716, 'min_child_weight': 1}. Best is trial 17 with value: 0.12426823835659428.
# [I 2025-10-27 20:22:21,797] Trial 28 finished with value: 0.1329359319147135 and parameters: {'n_estimators': 543, 'learning_rate': 0.02241489198370635, 'max_depth': 4, 'subsample': 0.8380529750662289, 'colsample_bytree': 0.9081473848217435, 'gamma': 0.13243774661128693, 'min_child_weight': 3}. Best is trial 17 with value: 0.12426823835659428.
# [I 2025-10-27 20:22:24,283] Trial 29 finished with value: 0.1303199869326835 and parameters: {'n_estimators': 686, 'learning_rate': 0.0863512819525503, 'max_depth': 5, 'subsample': 0.9593048561447032, 'colsample_bytree': 0.789024730508718, 'gamma': 0.02603674516639152, 'min_child_weight': 4}. Best is trial 17 with value: 0.12426823835659428.
# Best parameters: {'n_estimators': 795, 'learning_rate': 0.041781133811210534, 'max_depth': 4, 'subsample': 0.9004238636768309, 'colsample_bytree': 0.8861701514544139, 'gamma': 0.0007839147453102702, 'min_child_weight': 3}
# Best RMSE (CV): 0.12426823835659428

# %% [markdown]
# ## Xây dựng mô hình tốt nhất

# %%
import xgboost as xgb

best_params = {
    'n_estimators': 795,
    'learning_rate': 0.041781133811210534,
    'max_depth': 4,
    'subsample': 0.9004238636768309,
    'colsample_bytree': 0.8861701514544139,
    'gamma': 0.0007839147453102702,
    'min_child_weight': 3,
    'random_state': 42
}

best_model = xgb.XGBRegressor(**best_params)
best_model.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=0.8861701514544139, device=None,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, feature_weights=None,
#              gamma=0.0007839147453102702, grow_policy=None,
#              importance_type=None, interaction_constraints=None,
#              learning_rate=0.041781133811210534, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=3, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=795, n_jobs=None,
#              num_parallel_tree=None, ...)

# %% [markdown]
# ## Đây là bài toán hồi quy khác với bài toán phân loại nên phải đánh giá mô hình bằng các chỉ số RMSE, MAE, R²

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)

# %%
from sklearn.metrics import mean_squared_error, r2_score
import numpy as np
import pandas as pd

# 🔹 Dự đoán trên tập huấn luyện và validation
y_train_pred_log = best_model.predict(X_train)
y_val_pred_log = best_model.predict(X_val)

# 🔹 Tính RMSE (vì đã log-transform SalePrice)
rmse_train = np.sqrt(mean_squared_error(y_train, y_train_pred_log))
rmse_val = np.sqrt(mean_squared_error(y_val, y_val_pred_log))

# 🔹 Tính R² score
r2_train = r2_score(y_train, y_train_pred_log)
r2_val = r2_score(y_val, y_val_pred_log)

print(f"Hiệu suất mô hình XGBoost:")
print(f"RMSE (Train): {rmse_train:.5f}")
print(f"RMSE (Validation): {rmse_val:.5f}")
print(f"R² (Train): {r2_train:.4f}")
print(f"R² (Validation): {r2_val:.4f}")

# 🔹 Dự đoán giá thực tế (đảo log-transform)
y_val_pred = np.expm1(y_val_pred_log)
y_val_real = np.expm1(y_val)
# Out:
# Hiệu suất mô hình XGBoost:
# RMSE (Train): 0.03192
# RMSE (Validation): 0.03301
# R² (Train): 0.9936
# R² (Validation): 0.9942

# %% [markdown]
# Nhận xét:
#
# Mô hình có hiệu suất cao, R² train gần bằng R² validation cho thấy mô hình không overfit

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,6))
plt.scatter(y_val_real, y_val_pred, alpha=0.6)
plt.xlabel("Giá thực tế (SalePrice)")
plt.ylabel("Giá dự đoán (Predicted)")
plt.title("Biểu đồ so sánh Giá thực tế vs Dự đoán (Validation Set)")
plt.plot([y_val_real.min(), y_val_real.max()], [y_val_real.min(), y_val_real.max()], 'r--')
plt.show()

# %% [markdown]
# Nhận xét:
#
# Các điểm màu xanh (giá dự đoán vs giá thực tế) nằm rất sát với đường đỏ. Điều này chứng tỏ mô hình dự đoán rất chính xác, vì sai lệch giữa giá dự đoán và giá thật là rất nhỏ. Chỉ vài điểm lệch nhẹ ở vùng giá cao, có thể do dữ liệu ít ở vùng này (dữ liệu cao giá hiếm khi gặp)

# %% [markdown]
# ## Lưu mô hình này lại

# %%
import os
import joblib

os.makedirs('../models', exist_ok=True)
joblib.dump(best_model, '../models/xgboost_v1.pkl')
print("Mô hình đã được lưu vào '../models/xgboost_v1.pkl'")
# Out:
# Mô hình đã được lưu vào '../models/xgboost_v1.pkl'

# %% [markdown]
# ## Sử dụng mô hình đó để dự đoán trên dữ liệu test và tạo file nộp bài (submission file) cho Kaggle

# %%
import pandas as pd
import numpy as np
import joblib


df_train_clean = pd.read_csv("../data/03_processed/train_clean.csv")
df_test_clean = pd.read_csv("../data/03_processed/test_clean.csv")

y_train = df_train_clean["SalePrice"]
X_train = df_train_clean.drop(["SalePrice", "Id"], axis=1)

# 3. CHUẨN BỊ DỮ LIỆU TEST
X_test_raw = df_test_clean.drop("Id", axis=1)

# Đồng bộ cột giữa train và test:
# - Nếu test thiếu cột nào → thêm và gán 0
# - Nếu test thừa cột → loại bỏ
X_test = X_test_raw.reindex(columns=X_train.columns, fill_value=0)

print("Số cột sau khi đồng bộ:", X_test.shape[1])

#TẢI MÔ HÌNH TỐT NHẤT
model_path = "../models/xgboost_v1.pkl"
best_model = joblib.load(model_path)
print(f"Đã tải mô hình từ {model_path}")

# DỰ ĐOÁN TRÊN TẬP TEST
# Dự đoán log(SalePrice)
preds_test_log = best_model.predict(X_test)

# Chuyển ngược log → giá trị thật
preds_test_final = np.expm1(preds_test_log)

# TẠO FILE SUBMISSION
df_test_original = pd.read_csv("../data/01_raw/test.csv")

submission = pd.DataFrame({
    "Id": df_test_original["Id"],
    "SalePrice": preds_test_final
})

submission.to_csv("submission2.csv", index=False)
print("File submission.csv đã được tạo thành công!")
# Out:
# Số cột sau khi đồng bộ: 262
# Đã tải mô hình từ ../models/xgboost_v1.pkl
# File submission.csv đã được tạo thành công!

# %% [markdown]
# Kết quả file submission2.csv:

# %% [markdown]
# ![image.png](attachment:image.png)
